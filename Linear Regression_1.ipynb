# %% [markdown]
# # Linear Regression

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. 線性迴歸基本概念

# %% [markdown]
# #### 直線
#
# $$f(x) = 1.2x + 0.8$$

# %%
#準備 50 個點
#5-0/50 = 0.1 +....
# 0~5線性切割
x = np.linspace(0, 5, 50)
print(x)
# Out:
# [0.         0.10204082 0.20408163 0.30612245 0.40816327 0.51020408
#  0.6122449  0.71428571 0.81632653 0.91836735 1.02040816 1.12244898
#  1.2244898  1.32653061 1.42857143 1.53061224 1.63265306 1.73469388
#  1.83673469 1.93877551 2.04081633 2.14285714 2.24489796 2.34693878
#  2.44897959 2.55102041 2.65306122 2.75510204 2.85714286 2.95918367
#  3.06122449 3.16326531 3.26530612 3.36734694 3.46938776 3.57142857
#  3.67346939 3.7755102  3.87755102 3.97959184 4.08163265 4.18367347
#  4.28571429 4.3877551  4.48979592 4.59183673 4.69387755 4.79591837
#  4.89795918 5.        ]

# %%
y = 1.2*x + 0.8
y
# Out:
# array([0.8       , 0.92244898, 1.04489796, 1.16734694, 1.28979592,
#        1.4122449 , 1.53469388, 1.65714286, 1.77959184, 1.90204082,
#        2.0244898 , 2.14693878, 2.26938776, 2.39183673, 2.51428571,
#        2.63673469, 2.75918367, 2.88163265, 3.00408163, 3.12653061,
#        3.24897959, 3.37142857, 3.49387755, 3.61632653, 3.73877551,
#        3.86122449, 3.98367347, 4.10612245, 4.22857143, 4.35102041,
#        4.47346939, 4.59591837, 4.71836735, 4.84081633, 4.96326531,
#        5.08571429, 5.20816327, 5.33061224, 5.45306122, 5.5755102 ,
#        5.69795918, 5.82040816, 5.94285714, 6.06530612, 6.1877551 ,
#        6.31020408, 6.43265306, 6.55510204, 6.67755102, 6.8       ])

# %%
#畫圖
plt.scatter(x,y)
plt.plot(x, 1.2*x+0.8, 'r')

# %% [markdown]
# #### add noise
#
# $$f(x) + \varepsilon(x)$$

# %%
y = 1.2*x + 0.8 + 0.6*np.random.randn(50)
print(y)
# Out:
# [0.09522386 0.23775482 1.66749999 1.05986589 1.25824684 1.53794445
#  2.25932154 2.23801031 1.91286816 2.58198503 1.62148658 2.47164341
#  2.00895532 2.52301791 2.53044352 2.30402985 2.54198476 2.86913422
#  2.30754973 3.25888356 3.48729895 3.35209522 4.23772819 3.25146767
#  2.43830894 3.92337482 3.88363229 4.57560052 4.25334516 5.16249403
#  4.86407347 5.76916791 4.06976676 4.86233372 5.15937109 5.40850127
#  4.76253949 5.80311497 4.44482912 5.28990666 6.91795453 4.5482091
#  5.31457948 5.78843853 5.63433061 6.33717846 5.90376767 6.27818555
#  7.43493479 6.96711016]

# %%
plt.scatter(x,y)
plt.plot(x, 1.2*x + 0.8, 'r')

# %%
from sklearn.linear_model import LinearRegression
regr = LinearRegression()

# %%
regr
# Out:
# LinearRegression()

# %% [markdown]
# 要求資料轉換<br>
#
# $$[x_1, x_2, \ldots, x_{50}]$$
#
# ==>
#
# $$[[x_1], [x_2], \ldots, [x_{50}]]$$
#
#
# 矩陣的概念

# %%
print(x.shape)
X = x.reshape(-1,1)
X.shape
# Out:
# (50,)
# (50, 1)

# %%
regr.fit(X,y)
# Out:
# LinearRegression()

# %%
Y = regr.predict(X)
print(Y)
# Out:
# [0.86386486 0.98322506 1.10258526 1.22194546 1.34130566 1.46066586
#  1.58002606 1.69938627 1.81874647 1.93810667 2.05746687 2.17682707
#  2.29618727 2.41554747 2.53490767 2.65426787 2.77362807 2.89298827
#  3.01234847 3.13170867 3.25106887 3.37042908 3.48978928 3.60914948
#  3.72850968 3.84786988 3.96723008 4.08659028 4.20595048 4.32531068
#  4.44467088 4.56403108 4.68339128 4.80275148 4.92211168 5.04147188
#  5.16083209 5.28019229 5.39955249 5.51891269 5.63827289 5.75763309
#  5.87699329 5.99635349 6.11571369 6.23507389 6.35443409 6.47379429
#  6.59315449 6.71251469]

# %%
#了解你的訓練參數
regr.get_params()
# Out:
# {'copy_X': True,
#  'fit_intercept': True,
#  'n_jobs': None,
#  'normalize': 'deprecated',
#  'positive': False}

# %%
plt.scatter(x, y) #原本 
plt.plot(x, Y, 'ro') #預測
#calculate mse
mse = np.sum((Y-y)**2) / len(y)
print(mse)
# Out:
# 0.30831708773052624

# %%
#Y=WX+b
W=regr.coef_#斜率
W
# Out:
# array([1.16972997])

# %%
b=regr.intercept_ #截距
b
# Out:
# 0.8638648609049979

# %%
Y
# Out:
# array([0.86386486, 0.98322506, 1.10258526, 1.22194546, 1.34130566,
#        1.46066586, 1.58002606, 1.69938627, 1.81874647, 1.93810667,
#        2.05746687, 2.17682707, 2.29618727, 2.41554747, 2.53490767,
#        2.65426787, 2.77362807, 2.89298827, 3.01234847, 3.13170867,
#        3.25106887, 3.37042908, 3.48978928, 3.60914948, 3.72850968,
#        3.84786988, 3.96723008, 4.08659028, 4.20595048, 4.32531068,
#        4.44467088, 4.56403108, 4.68339128, 4.80275148, 4.92211168,
#        5.04147188, 5.16083209, 5.28019229, 5.39955249, 5.51891269,
#        5.63827289, 5.75763309, 5.87699329, 5.99635349, 6.11571369,
#        6.23507389, 6.35443409, 6.47379429, 6.59315449, 6.71251469])

# %%
#可以將新的x資料帶入算出結果
W*3+b
# Out:
# array([4.37305476])

# %%
y
# Out:
# array([0.09522386, 0.23775482, 1.66749999, 1.05986589, 1.25824684,
#        1.53794445, 2.25932154, 2.23801031, 1.91286816, 2.58198503,
#        1.62148658, 2.47164341, 2.00895532, 2.52301791, 2.53044352,
#        2.30402985, 2.54198476, 2.86913422, 2.30754973, 3.25888356,
#        3.48729895, 3.35209522, 4.23772819, 3.25146767, 2.43830894,
#        3.92337482, 3.88363229, 4.57560052, 4.25334516, 5.16249403,
#        4.86407347, 5.76916791, 4.06976676, 4.86233372, 5.15937109,
#        5.40850127, 4.76253949, 5.80311497, 4.44482912, 5.28990666,
#        6.91795453, 4.5482091 , 5.31457948, 5.78843853, 5.63433061,
#        6.33717846, 5.90376767, 6.27818555, 7.43493479, 6.96711016])
